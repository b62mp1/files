# %% [markdown]
# <a href="https://colab.research.google.com/github/b62mp1/files/blob/main/All_Modified.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
import yfinance as yf
import pandas_datareader
from pandas_datareader import data as pdr
yf.pdr_override()
from pandas.plotting import lag_plot
from statsmodels.tsa.arima_model import ARIMA
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import *
from keras import callbacks
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from google.colab import files

# %%
stock_names = ["TSLA", "GOOG", "AAPL", "AMZN", "FB"]
rnn_ls, arima_ls = [], []
for stock_name in stock_names:
  #df=pdr.get_data_yahoo(stock_name, start=(startDate), end=today).reset_index()
  df=pdr.get_data_yahoo(stock_name, start=('2020-01-01'), end='2022-04-19').reset_index()

  print("Number of rows and columns:", df.shape)
  df.head(5)
  # Check for missing values
  def num_missing(x):
      return sum(x.isnull())

  print("Missing values per column:")
  print(df.apply(num_missing, axis=0))

  print("\nMissing values per row:")
  print(df.apply(num_missing, axis=1).head())

  def window_dataset(series, window_size, batch_size=128,
                    shuffle_buffer=1000):
      dataset = tf.data.Dataset.from_tensor_slices(series)
      dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
      dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
      dataset = dataset.shuffle(shuffle_buffer)
      dataset = dataset.map(lambda window: (window[:-1], window[-1]))
      dataset = dataset.batch(batch_size).prefetch(1)
      return dataset

  def model_forecast(model, series, window_size):
      ds = tf.data.Dataset.from_tensor_slices(series)
      ds = ds.window(window_size, shift=1, drop_remainder=True)
      ds = ds.flat_map(lambda w: w.batch(window_size))
      ds = ds.batch(32).prefetch(1)
      forecast = model.predict(ds)
      return forecast

  # Split the data into training and test datasets
  split_index = int(len(df.values) * 0.80)
  training_set = df.iloc[:split_index, 4:5].values
  test_set = df.iloc[split_index:, 4:5].values
  # Normalizing and reshaping the training data

  # Feature Scaling
  sc = MinMaxScaler(feature_range = (0, 1))
  training_set_scaled = sc.fit_transform(training_set)
  # Creating a data structure with 60 time-steps and 1 output
  X_train = []
  y_train = []
  for i in range(60, split_index):
      X_train.append(training_set_scaled[i-60:i, 0])
      y_train.append(training_set_scaled[i, 0])
  X_train, y_train = np.array(X_train), np.array(y_train)
  X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
  X_train.shape
  # Normalizing and reshaping the testing data
  dataset_train = df.iloc[:split_index, 4:5]
  dataset_test = df.iloc[split_index:, 4:5]
  dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
  inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
  inputs = inputs.reshape(-1,1)
  inputs = sc.transform(inputs)
  X_test = []
  Y_test = []
  for i in range(60, len(dataset_total) - split_index + 60):
      X_test.append(inputs[i-60:i, 0])
      Y_test.append(inputs[i])
  X_test = np.array(X_test)
  Y_test = np.array(Y_test)
  X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
  print(X_test.shape)
  # Building a moving average model
  window = 20

  # Create a moving average over the entire dataset
  moving_avg = dataset_total.rolling(window=window).mean()

  # Slice the moving average on the forecast
  moving_avg_forecast = moving_avg.values[split_index - window : dataset_total.index.max() - window + 1]

  MAmse = mean_squared_error(dataset_test,moving_avg_forecast)
  from math import sqrt
  MArmse = sqrt(MAmse)
  MAr2Score = r2_score(dataset_test,moving_avg_forecast)
  # Building RNN model

  # Clear any back end stored data due to multiple iterations
  keras.backend.clear_session()
  tf.random.set_seed(42)
  np.random.seed(42)

  # Set window size
  window_size = 30

  # Create 2D batches of batch size and features (1 feature = 1 time step in window)
  train_set = window_dataset(training_set_scaled, window_size, batch_size=128)

  # Establish Model
  model_rnn = keras.models.Sequential([
    keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), # Add a 3rd dimension (feature dimensionality which in this case in univariate)
                        input_shape=[None]), # 1st dimension is batch size, input shape = None allows windows of any size to be used
    keras.layers.SimpleRNN(100, return_sequences=True), # takes in sequence (batch size, time, dimensionality per time step (univariate))
    keras.layers.SimpleRNN(100), # produces a single vector
    keras.layers.Dense(1), # produces 1 output 
  ])

  # Early stopping to prevent overfitting
  earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", patience=50, restore_best_weights=True)

  # Put model all together
  model_rnn.compile(loss='mean_squared_error',optimizer='adam')
  model_rnn.fit(train_set, epochs=100, batch_size=32)

  '''
  Y_hat = model_rnn.predict(X_test)
  RNNmse = mean_squared_error(Y_test,Y_hat)
  from math import sqrt
  RNNrmse = sqrt(RNNmse)
  RNNr2Score = r2_score(Y_test,Y_hat)

  RNNmse,RNNrmse,RNNr2Score
  '''
  # Predicting the values
  # All values normalized to training data
  spy_normalized_to_traindata = sc.transform(dataset_total.values.reshape(-1, 1))
  rnn_forecast = model_forecast(
      model_rnn,
      spy_normalized_to_traindata[split_index - window_size:-1],
      window_size)[:, 0]
  rnn_predicted_stock_price = sc.inverse_transform(rnn_forecast.reshape(-1,1)).flatten()
  #rnn_predicted_stock_price.shape

  RNNmse = mean_squared_error(dataset_test,rnn_predicted_stock_price)
  RNNrmse = sqrt(RNNmse)
  RNNr2Score = r2_score(dataset_test,rnn_predicted_stock_price)
  # Visualising the results
  plt.figure(figsize=(10, 5))
  plt.plot(df.loc[split_index:, 'Date'],dataset_test.values, color = 'red', label = 'Real ' + stock_name + ' Stock Price')
  plt.plot(df.loc[split_index:, 'Date'],moving_avg_forecast, color = 'blue', label = 'Predicted ' + stock_name + ' Stock Price')
  plt.ylabel('Dollars $')
  plt.xlabel('Days')
  plt.title('SMA Forecast vs Actual')
  plt.legend(loc="upper left")
  plt.savefig('SMA_' + stock_name + '.png')
  plt.show()
  files.download('SMA_' + stock_name + '.png')
  plt.figure(figsize=(10, 5))
  plt.plot(df.loc[split_index:, 'Date'],dataset_test.values, color = 'red', label = 'Real ' + stock_name + ' Stock Price')
  plt.plot(df.loc[split_index:, 'Date'],rnn_predicted_stock_price, color = 'blue', label = 'Predicted ' + stock_name + ' Stock Price')
  plt.ylabel('Dollars $')
  plt.xlabel('Days')
  plt.title('RNN Forecast vs Actual')
  plt.legend(loc="upper left")
  plt.savefig("RNN_" + stock_name + '.png')
  plt.show()
  files.download('RNN_' + stock_name + '.png')
  rnn_ls.append([stock_name, RNNmse, RNNrmse, RNNr2Score])
  arima_ls.append([stock_name, MAmse, MArmse, MAr2Score])

val_rnn = pd.DataFrame(rnn_ls, columns=['Stock Name', 'MSE', 'RMSE', 'R2 Score'])
val_rnn.to_csv('RNN.csv')

val_arima = pd.DataFrame(arima_ls, columns=['Stock Name', 'MSE', 'RMSE', 'R2 Score'])
val_arima.to_csv('ARIMA.csv')


files.download('RNN.csv')
files.download("ARIMA.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Number of rows and columns: (578, 7)
# Missing values per column:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Epoch 88/100
# 4/4 [==============================] - 0s 35ms/step - loss: 4.9595e-04
# Epoch 89/100
# 4/4 [==============================] - 0s 38ms/step - loss: 5.2108e-04
# Epoch 90/100
# 4/4 [==============================] - 0s 34ms/step - loss: 5.0595e-04
# Epoch 91/100
# 4/4 [==============================] - 0s 35ms/step - loss: 4.7745e-04
# Epoch 92/100
# 4/4 [==============================] - 0s 36ms/step - loss: 4.9259e-04
# Epoch 93/100
# 4/4 [==============================] - 0s 35ms/step - loss: 4.7459e-04
# Epoch 94/100
# 4/4 [==============================] - 0s 35ms/step - loss: 5.0145e-04
# Epoch 95/100
# 4/4 [==============================] - 0s 36ms/step - loss: 5.2119e-04
# Epoch 96/100
# 4/4 [==============================] - 0s 34ms/step - loss: 5.2149e-04
# Epoch 97/100
# 4/4 [==============================] - 0s 33ms/step - loss: 5.3473e-04
# Epoch 98/100
# 4/4 [==============================] - 0s 37ms/step - loss: 5.4800e-04
# Epoch 99/100
# 4/4 [==============================] - 0s 35ms/step - loss: 5.4442e-04
# Epoch 100/100
# 4/4 [==============================] - 0s 38ms/step - loss: 6.2453e-04
# [*********************100%***********************]  1 of 1 completed
# Number of rows and columns: (578, 7)
# Missing values per column:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
# Missing values per row:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64
# (116, 60, 1)
# Epoch 1/100
# 4/4 [==============================] - 2s 44ms/step - loss: 0.3851
# Epoch 2/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1082
# Epoch 3/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0434
# Epoch 4/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0227
# Epoch 5/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0136
# Epoch 6/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0099
# Epoch 7/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0097
# Epoch 8/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0074
# Epoch 9/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0048
# Epoch 10/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0033
# Epoch 11/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0026
# Epoch 12/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0026
# Epoch 13/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0023
# Epoch 14/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0021
# Epoch 15/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0019
# Epoch 16/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0017
# Epoch 17/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0015
# Epoch 18/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0015
# Epoch 19/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0014
# Epoch 20/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0015
# Epoch 21/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0014
# Epoch 22/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0014
# Epoch 23/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0013
# Epoch 24/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0013
# Epoch 25/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0013
# Epoch 26/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0013
# Epoch 27/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013
# Epoch 28/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0013
# Epoch 29/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0013
# Epoch 30/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013
# Epoch 31/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013
# Epoch 32/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0012
# Epoch 33/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0012
# Epoch 34/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0012
# Epoch 35/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0012
# Epoch 36/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012
# Epoch 37/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0012
# Epoch 38/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0012
# Epoch 39/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012
# Epoch 40/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0013
# Epoch 41/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0011
# Epoch 42/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0011
# Epoch 43/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0011
# Epoch 44/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0011
# Epoch 45/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0011
# Epoch 46/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0011
# Epoch 47/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0012
# Epoch 48/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0011
# Epoch 49/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0011
# Epoch 50/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0011
# Epoch 51/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0010
# Epoch 52/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0010
# Epoch 53/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0010
# Epoch 54/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0010
# Epoch 55/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0011
# Epoch 56/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012
# Epoch 57/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0011
# Epoch 58/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0010
# Epoch 59/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0010
# Epoch 60/100
# 4/4 [==============================] - 0s 44ms/step - loss: 9.8624e-04
# Epoch 61/100
# 4/4 [==============================] - 0s 35ms/step - loss: 9.8417e-04
# Epoch 62/100
# 4/4 [==============================] - 0s 35ms/step - loss: 9.5844e-04
# Epoch 63/100
# 4/4 [==============================] - 0s 39ms/step - loss: 9.4461e-04
# Epoch 64/100
# 4/4 [==============================] - 0s 35ms/step - loss: 9.3292e-04
# Epoch 65/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.

# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64
# (116, 60, 1)
# Epoch 1/100
# 4/4 [==============================] - 2s 43ms/step - loss: 0.3746
# Epoch 2/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0954
# Epoch 3/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0475
# Epoch 4/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0205
# Epoch 5/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0172
# Epoch 6/100
# 4/4 [==============================] - 1s 104ms/step - loss: 0.0092
# Epoch 7/100
# 4/4 [==============================] - 0s 95ms/step - loss: 0.0065
# Epoch 8/100
# 4/4 [==============================] - 1s 87ms/step - loss: 0.0063
# Epoch 9/100
# 4/4 [==============================] - 1s 81ms/step - loss: 0.0054
# Epoch 10/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0037
# Epoch 11/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0031
# Epoch 12/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0029
# Epoch 13/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0026
# Epoch 14/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0024
# Epoch 15/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0023
# Epoch 16/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0024
# Epoch 17/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0022
# Epoch 18/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0021
# Epoch 19/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0020
# Epoch 20/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0020
# Epoch 21/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0021
# Epoch 22/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0020
# Epoch 23/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0020
# Epoch 24/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0019
# Epoch 25/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0020
# Epoch 26/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0018
# Epoch 27/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0019
# Epoch 28/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0019
# Epoch 29/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0020
# Epoch 30/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0018
# Epoch 31/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0019
# Epoch 32/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0018
# Epoch 33/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0019
# Epoch 34/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0018
# Epoch 35/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0018
# Epoch 36/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0020
# Epoch 37/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0018
# Epoch 38/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0018
# Epoch 39/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0017
# Epoch 40/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0016
# Epoch 41/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0018
# Epoch 42/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0017
# Epoch 43/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0016
# Epoch 44/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0017
# Epoch 45/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0017
# Epoch 46/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0017
# Epoch 47/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0017
# Epoch 48/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0016
# Epoch 49/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0015
# Epoch 50/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0015
# Epoch 51/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0016
# Epoch 52/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0015
# Epoch 53/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0015
# Epoch 54/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0015
# Epoch 55/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0016
# Epoch 56/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0017
# Epoch 57/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0016
# Epoch 58/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0015
# Epoch 59/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0014
# Epoch 60/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0014
# Epoch 61/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0016
# Epoch 62/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0017
# Epoch 63/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0017
# Epoch 64/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0016
# Epoch 65/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0013
# Epoch 66/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0015
# Epoch 67/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0015
# Epoch 68/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0016
# Epoch 69/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0013
# Epoch 70/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0016
# Epoch 71/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0014
# Epoch 72/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0014
# Epoch 73/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0015
# Epoch 74/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0014
# Epoch 75/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0012
# Epoch 76/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0013
# Epoch 77/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0013
# Epoch 78/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0013
# Epoch 79/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0013
# Epoch 80/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0012
# Epoch 81/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0012
# Epoch 82/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0012
# Epoch 83/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0012
# Epoch 84/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0012
# Epoch 85/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0011
# Epoch 86/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0013
# Epoch 87/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0012
# Epoch 88/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0013
# Epoch 89/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013
# Epoch 90/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0013
# Epoch 91/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012
# Epoch 92/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0012
# Epoch 93/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0012
# Epoch 94/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0011
# Epoch 95/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0011
# Epoch 96/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0011
# Epoch 97/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0011
# Epoch 98/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0011
# Epoch 99/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0011
# Epoch 100/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012
# [*********************100%***********************]  1 of 1 completed
# Number of rows and columns: (578, 7)
# Missing values per column:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
# Missing values per row:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64
# (116, 60, 1)
# Epoch 1/100
# 4/4 [==============================] - 2s 42ms/step - loss: 0.3557
# Epoch 2/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1034
# Epoch 3/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0493
# Epoch 4/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0240
# Epoch 5/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0164
# Epoch 6/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0106
# Epoch 7/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0064
# Epoch 8/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0054
# Epoch 9/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0043
# Epoch 10/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0030
# Epoch 11/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0023
# Epoch 12/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0021
# Epoch 13/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0020
# Epoch 14/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0018
# Epoch 15/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0019
# Epoch 16/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0020
# Epoch 17/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0019
# Epoch 18/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0020
# Epoch 19/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0018
# Epoch 20/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0018
# Epoch 21/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0017
# Epoch 22/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0017
# Epoch 23/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0015
# Epoch 24/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0015
# Epoch 25/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0014
# Epoch 26/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0015
# Epoch 27/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0015
# Epoch 28/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0014
# Epoch 29/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0014
# Epoch 30/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0014
# Epoch 31/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0014
# Epoch 32/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0014
# Epoch 33/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0014
# Epoch 34/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0013
# Epoch 35/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0014
# Epoch 36/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0014
# Epoch 37/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0014
# Epoch 38/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0014
# Epoch 39/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0014
# Epoch 40/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0013
# Epoch 41/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0013
# Epoch 42/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0013
# Epoch 43/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0013
# Epoch 44/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0013
# Epoch 45/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0013
# Epoch 46/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0012
# Epoch 47/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0013
# Epoch 48/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0014
# Epoch 49/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013
# Epoch 50/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0014
# Epoch 51/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0012
# Epoch 52/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0012
# Epoch 53/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0013
# Epoch 54/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0012
# Epoch 55/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0013
# Epoch 56/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0014
# Epoch 57/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0013
# Epoch 58/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0014
# Epoch 59/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0012
# Epoch 60/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0012
# Epoch 61/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0012
# Epoch 62/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0012
# Epoch 63/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0013
# Epoch 64/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0012
# Epoch 65/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0012
# Epoch 66/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0012
# Epoch 67/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0014
# Epoch 68/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0015
# Epoch 69/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0012
# Epoch 70/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0014
# Epoch 71/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0016
# Epoch 72/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0014
# Epoch 73/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0012
# Epoch 74/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0011
# Epoch 75/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0010
# Epoch 76/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0010
# Epoch 77/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0010
# Epoch 78/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0010
# Epoch 79/100
# 4/4 [==============================] - 0s 39ms/step - loss: 9.9818e-04
# Epoch 80/100
# 4/4 [==============================] - 0s 36ms/step - loss: 9.8280e-04
# Epoch 81/100
# 4/4 [==============================] - 0s 35ms/step - loss: 9.8146e-04
# Epoch 82/100
# 4/4 [==============================] - 0s 35ms/step - loss: 9.8078e-04
# Epoch 83/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0011
# Epoch 84/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0011
# Epoch 85/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0010
# Epoch 86/100
# 4/4 [==============================] - 0s 40ms/step - loss: 9.6784e-04
# Epoch 87/100
# 4/4 [==============================] - 0s 35ms/step - loss: 9.5412e-04
# Epoch 88/100
# 4/4 [==============================] - 0s 41ms/step - loss: 9.5885e-04
# Epoch 89/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0011
# Epoch 90/100
# 4/4 [==============================] - 0s 35ms/step - loss: 9.7133e-04
# Epoch 91/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0011
# Epoch 92/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0011
# Epoch 93/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0010
# Epoch 94/100
# 4/4 [==============================] - 0s 37ms/step - loss: 9.1758e-04
# Epoch 95/100
# 4/4 [==============================] - 0s 36ms/step - loss: 8.9617e-04
# Epoch 96/100
# 4/4 [==============================] - 0s 39ms/step - loss: 9.8986e-04
# Epoch 97/100
# 4/4 [==============================] - 0s 36ms/step - loss: 9.1843e-04
# Epoch 98/100
# 4/4 [==============================] - 0s 40ms/step - loss: 8.9157e-04
# Epoch 99/100
# 4/4 [==============================] - 0s 37ms/step - loss: 9.2689e-04
# Epoch 100/100
# 4/4 [==============================] - 0s 37ms/step - loss: 9.1439e-04
